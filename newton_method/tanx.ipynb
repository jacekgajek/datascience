# %% [markdown]
# Performing Newtwon method to solve
#
# $$\tan x - x = 0$$
#
# We find roots of a function
#
# $$f(x) = \sin x - x\cos x$$
#
# with a derivative
#
# $$f^\prime(x)=x\sin x$$
#
# In the Newton method, the $n+1$-th solution is calculated with a formula
#
# $$
# x_{n+1} = x_n - \frac{f(x_n)}{f^\prime(x_n)} = x_n - \left(\frac{1}{x_n}-\frac{1}{\tan x_n}\right)
# $$
#
# The next approximate root location is found with assumption that roots are spaced more or less evenly
#
# $$
# x_0^{(k+2)} = x_0^{(k+1)} + \left|x_0^{(k+1)}-x_0^{(k)}\right|
# $$

# %%
# %reset

# %%
import plotly.express as px
import numpy as np
import IPython.display as dis


def f(x):
    return np.sin(x) - x*np.cos(x)
def df(x):
    return x*np.sin(x)

err = 1


def newton(x0):
    x = x0
    err = 1
    steps = 1
    while err > 0.0000000000001:
        # dx = f(x)/df(x)
        dx = 1.0/x - 1.0/np.tan(x)
        x1 = x - dx  #(np.tan(x) - x)/(1 / (1+x*x) - x)
        err = abs(x1 - x)
        x = x1
        steps = steps + 1
    return x, steps

problems =  range(1, 20)

x0=4.5
prevsol=3

for i in problems:
    sol, steps = newton(x0)
    # if abs(prevsol-sol) > 0.01:
    x0 = sol + abs(sol - prevsol)
    print(f"{i}) Result for x0 = {x0}:  {sol}     ({steps} steps)")
    prevsol = sol


X = np.linspace(30, 40, 200)
Y1 = [ np.tan(x) for x in X ]
Y2 = [ x for x in X ]

fig = px.line(x=X, y=[Y1, Y2], range_y=[-10, 50])
fig.show()
# Out:
# \\begin{align}Performing Newtwon method to solve\[\tan x - x = 0\]We find roots of a function\[f(x) = \sin x - x\cos x\]with a derivative\[f^\prime(x)=x\sin x\]\end{align}
# 1) Result for x0 = 5.986818915818128:  4.493409457909064     (5 steps)
# 2) Result for x0 = 4.493409457909064:  1.0511271186786075e-08     (48 steps)
# 3) Result for x0 = 8.986818905306858:  4.493409457909064     (2 steps)
# 4) Result for x0 = 10.95709421596635:  7.725251836937707     (9 steps)
# 5) Result for x0 = 14.082991481920091:  10.904121659428899     (5 steps)
# 6) Result for x0 = 17.228266166234047:  14.066193912831473     (5 steps)
# 7) Result for x0 = 20.375316631030067:  17.22075527193077     (5 steps)
# 8) Result for x0 = 23.521850646644353:  20.37130295928756     (4 steps)
# 9) Result for x0 = 26.66760203809045:  23.519452498689006     (4 steps)
# 10) Result for x0 = 29.812656018936345:  26.666054258812675     (4 steps)
# 11) Result for x0 = 32.95714332297324:  29.81159879089296     (4 steps)
# 12) Result for x0 = 36.10117928875199:  32.956389039822476     (4 steps)
# 13) Result for x0 = 39.24485544892874:  36.10062224437561     (4 steps)
# 14) Result for x0 = 42.38824247795278:  39.24443236116419     (4 steps)
# 15) Result for x0 = 45.53139477509965:  42.38791356813192     (4 steps)
# 16) Result for x0 = 48.67435445985063:  45.53113401399128     (4 steps)
# 17) Result for x0 = 51.817154449917496:  48.674144231954386     (4 steps)
# 18) Result for x0 = 54.95982074260495:  51.81698248727967     (4 steps)
# 19) Result for x0 = 58.1023740884982:  54.959678287888934     (4 steps)
# <div>                            <div id="fc247a0f-dc20-423c-b98c-4352d64b6098" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc247a0f-dc20-423c-b98c-4352d64b6098")) {                    Plotly.newPlot(                        "fc247a0f-dc20-423c-b98c-4352d64b6098",                        [{"hovertemplate":"variable=wide_variable_0<br>x=%{x}<br>value=%{y}<extra></extra>","legendgroup":"wide_variable_0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"wide_variable_0","orientation":"v","showlegend":true,"x":[30.0,30.050251256281406,30.100502512562816,30.150753768844222,30.201005025125628,30.251256281407034,30.301507537688444,30.35175879396985,30.402010050251256,30.452261306532662,30.502512562814072,30.55276381909548,30.603015075376884,30.65326633165829,30.7035175879397,30.753768844221106,30.804020100502512,30.85427135678392,30.90452261306533,30.954773869346734,31.00502512562814,31.055276381909547,31.105527638190956,31.155778894472363,31.20603015075377,31.256281407035175,31.306532663316585,31.35678391959799,31.407035175879397,31.457286432160803,31.507537688442213,31.55778894472362,31.608040201005025,31.65829145728643,31.70854271356784,31.758793969849247,31.809045226130653,31.85929648241206,31.90954773869347,31.959798994974875,32.01005025125628,32.06030150753769,32.11055276381909,32.1608040201005,32.21105527638191,32.26130653266332,32.311557788944725,32.36180904522613,32.41206030150754,32.462311557788944,32.51256281407035,32.562814070351756,32.61306532663317,32.663316582914575,32.71356783919598,32.76381909547739,32.814070351758794,32.8643216080402,32.914572864321606,32.96482412060301,33.015075376884425,33.06532663316583,33.11557788944724,33.165829145728644,33.21608040201005,33.266331658291456,33.31658291457286,33.36683417085427,33.41708542713568,33.46733668341709,33.517587939698494,33.5678391959799,33.618090452261306,33.66834170854271,33.71859296482412,33.768844221105525,33.81909547738694,33.869346733668344,33.91959798994975,33.969849246231156,34.02010050251256,34.07035175879397,34.120603015075375,34.17085427135679,34.221105527638194,34.2713567839196,34.321608040201006,34.37185929648241,34.42211055276382,34.472361809045225,34.52261306532663,34.57286432160804,34.62311557788945,34.67336683417086,34.72361809045226,34.77386934673367,34.824120603015075,34.87437185929648,34.92462311557789,34.9748743718593,35.02512562814071,35.07537688442211,35.12562814070352,35.175879396984925,35.22613065326633,35.27638190954774,35.32663316582914,35.37688442211055,35.42713567839196,35.47738693467337,35.527638190954775,35.57788944723618,35.62814070351759,35.678391959798994,35.7286432160804,35.77889447236181,35.82914572864322,35.879396984924625,35.92964824120603,35.97989949748744,36.030150753768844,36.08040201005025,36.130653266331656,36.18090452261306,36.231155778894475,36.28140703517588,36.33165829145729,36.381909547738694,36.4321608040201,36.482412060301506,36.53266331658291,36.582914572864325,36.63316582914573,36.68341708542714,36.733668341708544,36.78391959798995,36.834170854271356,36.88442211055276,36.93467336683417,36.984924623115575,37.03517587939699,37.085427135678394,37.1356783919598,37.185929648241206,37.23618090452261,37.28643216080402,37.336683417085425,37.38693467336684,37.437185929648244,37.48743718592965,37.537688442211056,37.58793969849246,37.63819095477387,37.688442211055275,37.73869346733668,37.78894472361809,37.8391959798995,37.88944723618091,37.93969849246231,37.98994974874372,38.040201005025125,38.09045226130653,38.14070351758794,38.19095477386935,38.24120603015076,38.29145728643216,38.34170854271357,38.391959798994975,38.44221105527638,38.49246231155779,38.5427135678392,38.5929648241206,38.64321608040201,38.69346733668342,38.743718592964825,38.79396984 ...
